# %%
print("hello world")
# Out:
# hello world

# %%
print("Welcome to Fantasy Quest!")
# Out:
# Welcome to Fantasy Quest!

# %%
sword_damage = 10
start_health = 100
end_health = start_health - sword_damage

print(f"sword damage: {sword_damage}")
print(f"start health: {start_health}")
print(f"end health: {end_health}")
# Out:
# sword damage: 10
# start health: 100
# end health: 90

# %% [markdown]
# Syntax: The rules for how expressions and statements should be structured in a language. Syntax errors aren't the only kind of problems you can run into when coding, for example:
#
# A bug in your logic. Your code is valid, and will run, but it does something unexpected.
# It's too slow. Your code is valid and does what's expected, but it does it slowly.

# %%
first = 5
second = 7
third = 9
average_value = (first + second + third) / 3
print(average_value)
# Out:
# 7.0

# %%
# single line comment
best_sword = "scimitar"
print(best_sword)
# Out:
# scimitar

# %% [markdown]
# Variable Names
# Variable names must not have spaces. They're continuous strings of characters.
#
# The creator of the Python language himself, Guido van Rossum, implores us to use snake_case for variable names. What is snake case? It's just a style for writing variable names. Here are some examples of different casing styles:

# %% [markdown]
# | Name | Description | Code | Language(s) that recommend it |
# |------|-------------|------|-------------------------------|
# | Snake Case | All words are lowercase and separated by underscores | `num_new_users` | Python, Ruby, Rust |
# | Camel Case | Capitalize the first letter of each word except the first one | `numNewUsers` | JavaScript, Java |
# | Pascal Case | Capitalize the first letter of each word | `NumNewUsers` | C#, C++ |

# %% [markdown]
# Strings
# In programming, snippets of text are called "strings". They're lists of characters strung together. We create strings by wrapping the text in single quotes or double quotes. That said, double quotes are preferred.

# %%
name_with_single_quotes = 'boot.dev' # not so good
name_with_double_quotes = "boot.dev" # so good

# %% [markdown]
# In Python, we can create strings that contain dynamic values with the f-string syntax.
#
# Add an f to the start of quotes to create an f-string: f"this is easy!"
# Use curly brackets {} around a variable to interpolate (put) its value into the string.
# Remember, it's just a string! Don't overthink it!

# %%
num_bananas = 10
bananas = f"You have {num_bananas} bananas"
print(bananas)
# You have 10 bananas
# Out:
# You have 10 bananas
